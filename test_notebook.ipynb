# %%
from yahoofinancials import YahooFinancials
from functions import manual_stock_analysis, get_ticker_symbols, retrieve_metrics_full_portfolio, display_portfolio, retrieve_metrics_per_stock
import sys

# %%
fin = YahooFinancials('AAPL')

# %%
stock_list = ['TSLA', 'AAPL', 'MSFT']
fin = YahooFinancials(stock_list)

# %%
fin.get_annual_avg_div_rate()
# Out:
# {'TSLA': 0.0, 'AAPL': 0.95, 'MSFT': 2.86}

# %%
[retrieve_metrics_per_stock(x) for x in ['TSLA', 'AAPL', 'MSFT']]
# Out:
# Price to revenue ratio of Tesla, Inc. :  5.727
# Marketcap of Tesla, Inc.: 530.68 B$
# Price to revenue ratio of Apple Inc. :  6.85
# Marketcap of Apple Inc.: 2607.21 B$
# Price to revenue ratio of Microsoft Corporation :  13.893
# Marketcap of Microsoft Corporation: 3131.48 B$
# [({'TSLA': {'exchange': 'NMS',
#     'quoteType': 'EQUITY',
#     'symbol': 'TSLA',
#     'underlyingSymbol': 'TSLA',
#     'shortName': 'Tesla, Inc.',
#     'longName': 'Tesla, Inc.',
#     'firstTradeDateEpochUtc': 1277818200,
#     'timeZoneFullName': 'America/New_York',
#     'timeZoneShortName': 'EDT',
#     'uuid': 'ec367bc4-f92c-397c-ac81-bf7b43cffaf7',
#     'messageBoardId': 'finmb_27444752',
#     'gmtOffSetMilliseconds': -14400000,
#     'maxAge': 1}},
#   {'TSLA': {'maxAge': 1,
#     'priceHint': 2,
#     'enterpriseValue': 554174840832,
#     'forwardPE': 42.291878,
#     'profitMargins': 0.15496999,
#     'floatShares': 2767646566,
#     'sharesOutstanding': 3184790016,
#     'sharesShort': 102298924,
#     'sharesShortPriorMonth': 88650365,
#     'sharesShortPreviousMonthDate': '-',
#     'dateShortInterest': 1710460800,
#     'sharesPercentSharesOut': 0.0321,
#     'heldPercentInsiders': 0.13,
#     'heldPercentInstitutions': 0.45771,
#     'shortRatio': 1.0,
#     'shortPercentOfFloat': 0.0369,
#     'beta': 2.415,
#     'impliedSharesOutstanding': 3184790016,
#     'category': None,
#     'bookValue': 19.665,
#     'priceToBook': 8.47343,
#     'fundFamily': None,
#     'legalType': None,
#     'lastFiscalYearEnd': 1703980800,
#     'nextFiscalYearEnd': 1735603200,
#     'mostRecentQuarter': 1703980800,
#     'earningsQuarterlyGrowth': 1.15,
#     'netIncomeToCommon': 14999000064,
#     'trailingEps': 4.3,
#     'forwardEps': 3.94,
#     'pegRatio': 3.94,
#     'lastSplitFactor': '3:1',
#     'lastSplitDate': '-',
#     'enterpriseToRevenue': 5.727,
#     'enterpriseToEbitda': 40.874,
#     '52WeekChange': -0.1018219,
#     'SandP52WeekChange': 0.2726959}},
#   {'TSLA': {'maxAge': 1,
#     'priceHint': 2,
#     'previousClose': 175.22,
#     'open': 164.689,
#     'dayLow': 163.43,
#     'dayHigh': 167.69,
#     'regularMarketPreviousClose': 175.22,
#     'regularMarketOpen': 164.689,
#     'regularMarketDayLow': 163.43,
#     'regularMarketDayHigh': 167.69,
#     'payoutRatio': 0.0,
#     'beta': 2.415,
#     'trailingPE': 38.751163,
#     'forwardPE': 42.291878,
#     'volume': 116035217,
#     'regularMarketVolume': 116035217,
#     'averageVolume': 102210573,
#     'averageVolume10days': 85460970,
#     'averageDailyVolume10Day': 85460970,
#     'bid': 152.05,
#     'ask': 166.82,
#     'bidSize': 200,
#     'askSize': 1000,
#     'marketCap': 530681561088,
#     'fiftyTwoWeekLow': 152.37,
#     'fiftyTwoWeekHigh': 299.29,
#     'priceToSalesTrailing12Months': 5.483777,
#     'fiftyDayAverage': 185.6486,
#     'twoHundredDayAverage': 231.26775,
#     'trailingAnnualDividendRate': 0.0,
#     'trailingAnnualDividendYield': 0.0,
#     'currency': 'USD',
#     'fromCurrency': None,
#     'toCurrency': None,
#     'lastMarket': None,
#     'coinMarketCapLink': None,
#     'algorithm': None,
#     'tradeable': False}}),
#  ({'AAPL': {'exchange': 'NMS',
#     'quoteType': 'EQUITY',
#     'symbol': 'AAPL',
#     'underlyingSymbol': 'AAPL',
#     'shortName': 'Apple Inc.',
#     'longName': 'Apple Inc.',
#     'firstTradeDateEpochUtc': 345479400,
#     'timeZoneFullName': 'America/New_York',
#     'timeZoneShortName': 'EDT',
#     'uuid': '8b10e4ae-9eeb-3684-921a-9ab27e4d87aa',
#     'messageBoardId': 'finmb_24937',
#     'gmtOffSetMilliseconds': -14400000,
#     'maxAge': 1}},
#   {'AAPL': {'maxAge': 1,
#     'priceHint': 2,
#     'enterpriseValue': 2642147278848,
#     'forwardPE': 23.581005,
#     'profitMargins': 0.26163,
#     'floatShares': 15414548871,
#     'sharesOutstanding': 15441899520,
#     'sharesShort': 110863064,
#     'sharesShortPriorMonth': 97665956,
#     'sharesShortPreviousMonthDate': '-',
#     'dateShortInterest': 1710460800,
#     'sharesPercentSharesOut': 0.0072000003,
#     'heldPercentInsiders': 0.059359998,
#     'heldPercentInstitutions': 0.56681,
#     'shortRatio': 1.64,
#     'shortPercentOfFloat': 0.0072000003,
#     'beta': 1.289,
#     'impliedSharesOutstanding': 15615699968,
#     'category': None,
#     'bookValue': 4.793,
#     'priceToBook': 35.226368,
#     'fundFamily': None,
#     'legalType': None,
#     'lastFiscalYearEnd': 1696032000,
#     'nextFiscalYearEnd': 1727654400,
#     'mostRecentQuarter': 1703894400,
#     'earningsQuarterlyGrowth': 0.131,
#     'netIncomeToCommon': 100912996352,
#     'trailingEps': 6.44,
#     'forwardEps': 7.16,
#     'pegRatio': 2.36,
#     'lastSplitFactor': '4:1',
#     'lastSplitDate': '-',
#     'enterpriseToRevenue': 6.85,
#     'enterpriseToEbitda': 20.307,
#     '52WeekChange': 0.03163171,
#     'SandP52WeekChange': 0.2726959,
#     'lastDividendValue': 0.24,
#     'lastDividendDate': '-'}},
#   {'AAPL': {'maxAge': 1,
#     'priceHint': 2,
#     'previousClose': 170.03,
#     'open': 169.06,
#     'dayLow': 168.2302,
#     'dayHigh': 169.34,
#     'regularMarketPreviousClose': 170.03,
#     'regularMarketOpen': 169.06,
#     'regularMarketDayLow': 168.2302,
#     'regularMarketDayHigh': 169.34,
#     'dividendRate': 0.96,
#     'dividendYield': 0.0057,
#     'exDividendDate': '-',
#     'payoutRatio': 0.14770001,
#     'fiveYearAvgDividendYield': 0.74,
#     'beta': 1.289,
#     'trailingPE': 26.21739,
#     'forwardPE': 23.581005,
#     'volume': 47248438,
#     'regularMarketVolume': 47248438,
#     'averageVolume': 61103804,
#     'averageVolume10days': 61585368,
#     'averageDailyVolume10Day': 61585368,
#     'bid': 155.08,
#     'ask': 182.06,
#     'bidSize': 200,
#     'askSize': 200,
#     'marketCap': 2607210299392,
#     'fiftyTwoWeekLow': 159.78,
#     'fiftyTwoWeekHigh': 199.62,
#     'priceToSalesTrailing12Months': 6.759579,
#     'fiftyDayAverage': 179.7492,
#     'twoHundredDayAverage': 183.44028,
#     'trailingAnnualDividendRate': 0.95,
#     'trailingAnnualDividendYield': 0.005587249,
#     'currency': 'USD',
#     'fromCurrency': None,
#     'toCurrency': None,
#     'lastMarket': None,
#     'coinMarketCapLink': None,
#     'algorithm': None,
#     'tradeable': False}}),
#  ({'MSFT': {'exchange': 'NMS',
#     'quoteType': 'EQUITY',
#     'symbol': 'MSFT',
#     'underlyingSymbol': 'MSFT',
#     'shortName': 'Microsoft Corporation',
#     'longName': 'Microsoft Corporation',
#     'firstTradeDateEpochUtc': 511108200,
#     'timeZoneFullName': 'America/New_York',
#     'timeZoneShortName': 'EDT',
#     'uuid': 'b004b3ec-de24-385e-b2c1-923f10d3fb62',
#     'messageBoardId': 'finmb_21835',
#     'gmtOffSetMilliseconds': -14400000,
#     'maxAge': 1}},
#   {'MSFT': {'maxAge': 1,
#     'priceHint': 2,
#     'enterpriseValue': 3161859031040,
#     'forwardPE': 31.521317,
#     'profitMargins': 0.36269,
#     'floatShares': 7418919053,
#     'sharesOutstanding': 7430439936,
#     'sharesShort': 54210656,
#     'sharesShortPriorMonth': 42451775,
#     'sharesShortPreviousMonthDate': '-',
#     'dateShortInterest': 1710460800,
#     'sharesPercentSharesOut': 0.0073,
#     'heldPercentInsiders': 0.00054000004,
#     'heldPercentInstitutions': 0.73844004,
#     'shortRatio': 2.46,
#     'shortPercentOfFloat': 0.0073,
#     'beta': 0.89,
#     'impliedSharesOutstanding': 7430439936,
#     'category': None,
#     'bookValue': 32.06,
#     'priceToBook': 13.145352,
#     'fundFamily': None,
#     'legalType': None,
#     'lastFiscalYearEnd': 1688083200,
#     'nextFiscalYearEnd': 1719705600,
#     'mostRecentQuarter': 1703980800,
#     'earningsQuarterlyGrowth': 0.332,
#     'netIncomeToCommon': 82541002752,
#     'trailingEps': 11.04,
#     'forwardEps': 13.37,
#     'pegRatio': 2.24,
#     'lastSplitFactor': '2:1',
#     'lastSplitDate': '-',
#     'enterpriseToRevenue': 13.893,
#     'enterpriseToEbitda': 26.699,
#     '52WeekChange': 0.48216927,
#     'SandP52WeekChange': 0.2726959,
#     'lastDividendValue': 0.75,
#     'lastDividendDate': '-'}},
#   {'MSFT': {'maxAge': 1,
#     'priceHint': 2,
#     'previousClose': 424.57,
#     'open': 420.158,
#     'dayLow': 417.842,
#     'dayHigh': 422.38,
#     'regularMarketPreviousClose': 424.57,
#     'regularMarketOpen': 420.158,
#     'regularMarketDayLow': 417.842,
#     'regularMarketDayHigh': 422.38,
#     'dividendRate': 3.0,
#     'dividendYield': 0.0070999996,
#     'exDividendDate': '-',
#     'payoutRatio': 0.2523,
#     'fiveYearAvgDividendYield': 0.95,
#     'beta': 0.89,
#     'trailingPE': 38.173912,
#     'forwardPE': 31.521317,
#     'volume': 17722802,
#     'regularMarketVolume': 17722802,
#     'averageVolume': 22698309,
#     'averageVolume10days': 18218481,
#     'averageDailyVolume10Day': 18218481,
#     'bid': 386.34,
#     'ask': 453.57,
#     'bidSize': 200,
#     'askSize': 200,
#     'marketCap': 3131484667904,
#     'fiftyTwoWeekLow': 275.37,
#     'fiftyTwoWeekHigh': 430.82,
#     'priceToSalesTrailing12Months': 13.7597475,
#     'fiftyDayAverage': 412.2742,
#     'twoHundredDayAverage': 364.00717,
#     'trailingAnnualDividendRate': 2.86,
#     'trailingAnnualDividendYield': 0.006736227,
#     'currency': 'USD',
#     'fromCurrency': None,
#     'toCurrency': None,
#     'lastMarket': None,
#     'coinMarketCapLink': None,
#     'algorithm': None,
#     'tradeable': False}})]
